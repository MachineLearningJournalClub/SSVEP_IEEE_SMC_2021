# %%
import mne

raw = mne.io.read_raw_fif("D:\Desktop\SSVEP\data_raw.fif", preload = True)
raw.plot(start=1, duration=50)
# Out:
# Opening raw data file D:\Desktop\SSVEP\data_raw.fif...
# Isotrak not found
#     Range : 0 ... 57727 =      0.000 ...   225.496 secs
# Ready.
# Reading 0 ... 57727  =      0.000 ...   225.496 secs...
# <MNEBrowseFigure size 432x288 with 4 Axes>
# <MNEBrowseFigure size 432x288 with 4 Axes>

# %%
#Common average reference

raw_eeg = raw.pick_types(eeg=True)

raw_avg_ref = raw_eeg.copy().set_eeg_reference(ref_channels='average')
# Out:
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
